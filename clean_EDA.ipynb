# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',500)

# %%
def get_clean_data(filename):
    df = pd.read_csv('../capstone_data/Azimuth/clean/{}_clean.csv'.format(filename))
    df['t'] = pd.to_datetime(df['t'], format='%Y-%m-%d %H:%M:%S')
    df.set_index('t',inplace=True)
    return df

# %%
df1 = get_clean_data('project_6d8c')
df2 = get_clean_data('project_1074')
df3 = get_clean_data('project_4229')
df4 = get_clean_data('project_5526')
df5 = get_clean_data('project_bc67')

# %%
dfs = [df1,df2,df3,df4,df5]
for df in dfs:
    print 'start: {}   end: {}'.format(df.index.min(),df.index.max())
# Out:
# start: 2016-10-13 10:30:00   end: 2017-01-29 06:30:00
# start: 2017-05-27 00:00:00   end: 2017-08-11 12:00:00
# start: 2016-05-18 00:00:00   end: 2017-02-28 23:55:00
# start: 2016-02-15 16:00:00   end: 2017-08-14 15:15:00
# start: 2016-10-15 00:00:00   end: 2017-01-08 00:30:00

# %%
def plot_all_data(df,columns):
    years = df['year'].unique()
    y_m_combinations = []
    for y in years: 
        months = df[(df['year'] == y)]['month'].unique()
        for m in months:
            y_m = (y,m)
            y_m_combinations.append(y_m)

    fig, axs = plt.subplots(len(y_m_combinations), figsize=(14, 5*len(y_m_combinations)))
    for ax, c in zip(axs,y_m_combinations):
        temp = df[(df['year'] == c[0]) & (df['month'] == c[1])]
        for col in columns:
            ax.plot(temp.index, temp[col])
        ax.set_title('timeseries for {}, {}'.format(c[0],c[1]))
        ax.fill_between(temp.index, 0,150, where=temp['relay_est'].values == 1, facecolor='red', alpha=0.5)
    plt.show()
    pass

# %%
def plot_time_frame(df,start,end,columns):
    '''
    Plot the timeseries for a given period of time
    PARAMETERS
    ------------
    df : Pandas DataFrame with DatetimeIndex
    start: string in format 'YYYY-MM-DD HH:MM:SS'
    end: string in format 'YYYY-MM-DD HH:MM:SS'
    columns: list of column names
    RETURNS
    -------
    None: plots the graphs
    '''
    temp = df.loc[(df.index>=start)&(df.index<end)]
    years = temp['year'].unique()
    y_m_combinations = []
    for y in years: 
        months = temp[(temp['year'] == y)]['month'].unique()
        for m in months:
            y_m = (y,m)
            y_m_combinations.append(y_m)
    
    if len(y_m_combinations) ==1:
        temp2 = temp[(temp['year'] == y_m_combinations[0][0]) & (temp['month'] == y_m_combinations[0][1])]
        plt.figure(figsize=(14,4))
        for col in columns:
            plt.plot(temp2.index, temp2[col]/df[col].max())
        plt.title('timeseries for {}, {}'.format(y_m_combinations[0][0],y_m_combinations[0][0]))
        
    else:
        fig, axs = plt.subplots(len(y_m_combinations), figsize=(14, len(y_m_combinations)*4))
        for ax, c in zip(axs,y_m_combinations):
            temp2 = temp[(temp['year'] == c[0]) & (temp['month'] == c[1])]
            for col in columns:
                ax.plot(temp2.index, temp2[col]/df[col].max())
            ax.set_title('timeseries for {}, {}'.format(c[0],c[1]))
    plt.show()
    pass

# %%
df_34 = df3.merge(df4,how='outer', left_index=True, right_index=True)

# %%
df_34.dropna(inplace=True)

# %% [markdown]
# ## Sum indication that there is correlation between outages.

# %%
df_34.groupby('relay_est_x')['relay_est_y'].mean()
# Out:
# relay_est_x
# 0.0    0.177925
# 1.0    0.534934
# Name: relay_est_y, dtype: float64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Ideas:
# - frequency of outages in the preceeding day
# - Variance in the voltage of the last hour
# - Deviation of the voltage mean.
# - Amperes...

# %% [markdown]
# ### Count of hours of outages in a preceeding timeframe

# %%
temp = pd.DataFrame(df2.relay_est)
result = pd.rolling_sum(temp.relay_est.shift(), window=24*12*7)
df2['week_hours_outage'] = result
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19687 entries, 2017-05-27 00:00:00 to 2017-08-11 12:00:00
# Data columns (total 17 columns):
# project_id           19687 non-null object
# relay                19687 non-null float64
# load_v1rms           19687 non-null float64
# load_v2rms           19687 non-null float64
# load_v3rms           19687 non-null float64
# load_i1rms           19687 non-null float64
# load_i2rms           19687 non-null float64
# laod_i3rms           19687 non-null float64
# year                 19687 non-null int64
# month                19687 non-null int64
# day                  19687 non-null int64
# dayofweek            19687 non-null int64
# hour                 19687 non-null int64
# relay_est            19687 non-null int64
# t_diff               19675 non-null float64
# data_issue           19687 non-null int64
# week_hours_outage    17671 non-null float64
# dtypes: float64(9), int64(7), object(1)
# memory usage: 2.7+ MB
# /home/rosina/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pd.rolling_sum is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=2016,center=False).sum()

# %% [markdown]
# ### Indicator for beginning of gen

# %%
df2['begin_gen'] = df2.relay_est.shift(1)
df2['begin_gen'] = df2['relay_est']-df2['begin_gen']
df2['begin_gen'] = df2['begin_gen'].apply(lambda x: 1 if x== 1 else 0)

# %%
temp = pd.DataFrame(df2.begin_gen)
result = pd.rolling_sum(temp.begin_gen.shift(), window=24*12*7)
df2['week_count_outage'] = result
# Out:
# /home/rosina/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pd.rolling_sum is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=2016,center=False).sum()

# %%
plot_all_data(df2,['relay_est','week_hours_outage','week_count_outage'])

# %%
df2[datetime(2017,8,2,10):datetime(2017,8,3)][['relay_est','week_hours_outage','week_count_outage','begin_gen']]
# Out:
#                      relay_est  week_hours_outage  week_count_outage  \
# t
# 2017-08-02 10:00:00          0               79.0                4.0
# 2017-08-02 10:05:00          0               79.0                4.0
# 2017-08-02 10:10:00          0               79.0                4.0
# 2017-08-02 10:15:00          0               79.0                4.0
# 2017-08-02 10:20:00          0               79.0                4.0
# 2017-08-02 10:25:00          1               79.0                4.0
# 2017-08-02 10:30:00          1               80.0                5.0
# 2017-08-02 10:35:00          1               81.0                5.0
# 2017-08-02 10:40:00          1               82.0                5.0
# 2017-08-02 10:45:00          1               83.0                5.0
# 2017-08-02 10:50:00          1               84.0                5.0
# 2017-08-02 10:55:00          1               85.0                5.0
# 2017-08-02 11:00:00          1               86.0                5.0
# 2017-08-02 11:05:00          1               87.0                5.0
# 2017-08-02 11:10:00          1               88.0                5.0
# 2017-08-02 11:15:00          1               89.0                5.0
# 2017-08-02 11:20:00          1               90.0                5.0
# 2017-08-02 11:25:00          1               91.0                5.0
# 2017-08-02 11:30:00          1               92.0                5.0
# 2017-08-02 11:35:00          1               93.0                5.0
# 2017-08-02 11:40:00          1               94.0                5.0
# 2017-08-02 11:45:00          1               95.0                5.0
# 2017-08-02 11:50:00          1               96.0                5.0
# 2017-08-02 11:55:00          1               97.0                5.0
# 2017-08-02 12:00:00          1               98.0                5.0
# 2017-08-02 12:05:00          1               99.0                5.0
# 2017-08-02 12:10:00          1              100.0                5.0
# 2017-08-02 12:15:00          1              101.0                5.0
# 2017-08-02 12:20:00          1              102.0                5.0
# 2017-08-02 12:25:00          1              103.0                5.0
# ...                        ...                ...                ...
# 2017-08-02 21:35:00          0              142.0                6.0
# 2017-08-02 21:40:00          0              142.0                6.0
# 2017-08-02 21:45:00          0              142.0                6.0
# 2017-08-02 21:50:00          0              142.0                6.0
# 2017-08-02 21:55:00          0              142.0                6.0
# 2017-08-02 22:00:00          0              142.0                6.0
# 2017-08-02 22:05:00          0              142.0                6.0
# 2017-08-02 22:10:00          0              142.0                6.0
# 2017-08-02 22:15:00          0              142.0                6.0
# 2017-08-02 22:20:00          0              142.0                6.0
# 2017-08-02 22:25:00          0              142.0                6.0
# 2017-08-02 22:30:00          0              142.0                6.0
# 2017-08-02 22:35:00          0              142.0                6.0
# 2017-08-02 22:40:00          0              142.0                6.0
# 2017-08-02 22:45:00          0              142.0                6.0
# 2017-08-02 22:50:00          0              142.0                6.0
# 2017-08-02 22:55:00          0              142.0                6.0
# 2017-08-02 23:00:00          0              142.0                6.0
# 2017-08-02 23:05:00          0              142.0                6.0
# 2017-08-02 23:10:00          0              142.0                6.0
# 2017-08-02 23:15:00          0              142.0                6.0
# 2017-08-02 23:20:00          0              142.0                6.0
# 2017-08-02 23:25:00          0              142.0                6.0
# 2017-08-02 23:30:00          0              142.0                6.0
# 2017-08-02 23:35:00          0              142.0                6.0
# 2017-08-02 23:40:00          0              142.0                6.0
# 2017-08-02 23:45:00          0              142.0                6.0
# 2017-08-02 23:50:00          0              142.0                6.0
# 2017-08-02 23:55:00          0              142.0                6.0
# 2017-08-03 00:00:00          0              142.0                6.0
#
#                      begin_gen
# t
# 2017-08-02 10:00:00          0
# 2017-08-02 10:05:00          0
# 2017-08-02 10:10:00          0
# 2017-08-02 10:15:00          0
# 2017-08-02 10:20:00          0
# 2017-08-02 10:25:00          1
# 2017-08-02 10:30:00          0
# 2017-08-02 10:35:00          0
# 2017-08-02 10:40:00          0
# 2017-08-02 10:45:00          0
# 2017-08-02 10:50:00          0
# 2017-08-02 10:55:00          0
# 2017-08-02 11:00:00          0
# 2017-08-02 11:05:00          0
# 2017-08-02 11:10:00          0
# 2017-08-02 11:15:00          0
# 2017-08-02 11:20:00          0
# 2017-08-02 11:25:00          0
# 2017-08-02 11:30:00          0
# 2017-08-02 11:35:00          0
# 2017-08-02 11:40:00          0
# 2017-08-02 11:45:00          0
# 2017-08-02 11:50:00          0
# 2017-08-02 11:55:00          0
# 2017-08-02 12:00:00          0
# 2017-08-02 12:05:00          0
# 2017-08-02 12:10:00          0
# 2017-08-02 12:15:00          0
# 2017-08-02 12:20:00          0
# 2017-08-02 12:25:00          0
# ...                        ...
# 2017-08-02 21:35:00          0
# 2017-08-02 21:40:00          0
# 2017-08-02 21:45:00          0
# 2017-08-02 21:50:00          0
# 2017-08-02 21:55:00          0
# 2017-08-02 22:00:00          0
# 2017-08-02 22:05:00          0
# 2017-08-02 22:10:00          0
# 2017-08-02 22:15:00          0
# 2017-08-02 22:20:00          0
# 2017-08-02 22:25:00          0
# 2017-08-02 22:30:00          0
# 2017-08-02 22:35:00          0
# 2017-08-02 22:40:00          0
# 2017-08-02 22:45:00          0
# 2017-08-02 22:50:00          0
# 2017-08-02 22:55:00          0
# 2017-08-02 23:00:00          0
# 2017-08-02 23:05:00          0
# 2017-08-02 23:10:00          0
# 2017-08-02 23:15:00          0
# 2017-08-02 23:20:00          0
# 2017-08-02 23:25:00          0
# 2017-08-02 23:30:00          0
# 2017-08-02 23:35:00          0
# 2017-08-02 23:40:00          0
# 2017-08-02 23:45:00          0
# 2017-08-02 23:50:00          0
# 2017-08-02 23:55:00          0
# 2017-08-03 00:00:00          0
#
# [169 rows x 4 columns]

# %%
df2[['load_v1rms','load_v2rms','load_v3rms']].mean()
# Out:
# load_v1rms    229.563055
# load_v2rms    233.243577
# load_v3rms    234.158416
# dtype: float64

# %%
temp = pd.DataFrame(df2.load_v1rms.shift(1))
result = temp.rolling('H',min_periods=5).std()
df2['v1rms_hr_std'] = result
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19687 entries, 2017-05-27 00:00:00 to 2017-08-11 12:00:00
# Data columns (total 20 columns):
# project_id           19687 non-null object
# relay                19687 non-null float64
# load_v1rms           19687 non-null float64
# load_v2rms           19687 non-null float64
# load_v3rms           19687 non-null float64
# load_i1rms           19687 non-null float64
# load_i2rms           19687 non-null float64
# laod_i3rms           19687 non-null float64
# year                 19687 non-null int64
# month                19687 non-null int64
# day                  19687 non-null int64
# dayofweek            19687 non-null int64
# hour                 19687 non-null int64
# relay_est            19687 non-null int64
# t_diff               19675 non-null float64
# data_issue           19687 non-null int64
# week_hours_outage    17671 non-null float64
# begin_gen            19687 non-null int64
# week_count_outage    17671 non-null float64
# v1rms_hr_std         19654 non-null float64
# dtypes: float64(11), int64(8), object(1)
# memory usage: 3.8+ MB

# %%
temp = pd.DataFrame(df2.load_v2rms.shift(1))
result = temp.rolling('H',min_periods=5).std()
df2['v2rms_hr_std'] = result
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19687 entries, 2017-05-27 00:00:00 to 2017-08-11 12:00:00
# Data columns (total 21 columns):
# project_id           19687 non-null object
# relay                19687 non-null float64
# load_v1rms           19687 non-null float64
# load_v2rms           19687 non-null float64
# load_v3rms           19687 non-null float64
# load_i1rms           19687 non-null float64
# load_i2rms           19687 non-null float64
# laod_i3rms           19687 non-null float64
# year                 19687 non-null int64
# month                19687 non-null int64
# day                  19687 non-null int64
# dayofweek            19687 non-null int64
# hour                 19687 non-null int64
# relay_est            19687 non-null int64
# t_diff               19675 non-null float64
# data_issue           19687 non-null int64
# week_hours_outage    17671 non-null float64
# begin_gen            19687 non-null int64
# week_count_outage    17671 non-null float64
# v1rms_hr_std         19654 non-null float64
# v2rms_hr_std         19654 non-null float64
# dtypes: float64(12), int64(8), object(1)
# memory usage: 3.9+ MB

# %%
temp = pd.DataFrame(df2.load_v3rms.shift(1))
result = temp.rolling('H',min_periods=5).std()
df2['v3rms_hr_std'] = result
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19687 entries, 2017-05-27 00:00:00 to 2017-08-11 12:00:00
# Data columns (total 22 columns):
# project_id           19687 non-null object
# relay                19687 non-null float64
# load_v1rms           19687 non-null float64
# load_v2rms           19687 non-null float64
# load_v3rms           19687 non-null float64
# load_i1rms           19687 non-null float64
# load_i2rms           19687 non-null float64
# laod_i3rms           19687 non-null float64
# year                 19687 non-null int64
# month                19687 non-null int64
# day                  19687 non-null int64
# dayofweek            19687 non-null int64
# hour                 19687 non-null int64
# relay_est            19687 non-null int64
# t_diff               19675 non-null float64
# data_issue           19687 non-null int64
# week_hours_outage    17671 non-null float64
# begin_gen            19687 non-null int64
# week_count_outage    17671 non-null float64
# v1rms_hr_std         19654 non-null float64
# v2rms_hr_std         19654 non-null float64
# v3rms_hr_std         19654 non-null float64
# dtypes: float64(13), int64(8), object(1)
# memory usage: 4.1+ MB

# %%
temp = pd.DataFrame(df2.load_i1rms.shift(1))
result = temp.rolling('H',min_periods=5).std()
df2['i1rms_hr_std'] = result
temp = pd.DataFrame(df2.load_i2rms.shift(1))
result = temp.rolling('H',min_periods=5).std()
df2['i2rms_hr_std'] = result
temp = pd.DataFrame(df2.laod_i3rms.shift(1))
result = temp.rolling('H',min_periods=5).std()
df2['i3rms_hr_std'] = result

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19687 entries, 2017-05-27 00:00:00 to 2017-08-11 12:00:00
# Data columns (total 25 columns):
# project_id           19687 non-null object
# relay                19687 non-null float64
# load_v1rms           19687 non-null float64
# load_v2rms           19687 non-null float64
# load_v3rms           19687 non-null float64
# load_i1rms           19687 non-null float64
# load_i2rms           19687 non-null float64
# laod_i3rms           19687 non-null float64
# year                 19687 non-null int64
# month                19687 non-null int64
# day                  19687 non-null int64
# dayofweek            19687 non-null int64
# hour                 19687 non-null int64
# relay_est            19687 non-null int64
# t_diff               19675 non-null float64
# data_issue           19687 non-null int64
# week_hours_outage    17671 non-null float64
# begin_gen            19687 non-null int64
# week_count_outage    17671 non-null float64
# v1rms_hr_std         19654 non-null float64
# v2rms_hr_std         19654 non-null float64
# v3rms_hr_std         19654 non-null float64
# i1rms_hr_std         19654 non-null float64
# i2rms_hr_std         19654 non-null float64
# i3rms_hr_std         19654 non-null float64
# dtypes: float64(16), int64(8), object(1)
# memory usage: 4.5+ MB

# %%
plot_all_data(df2,['v1rms_hr_std','load_v1rms'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19687 entries, 2017-05-27 00:00:00 to 2017-08-11 12:00:00
# Data columns (total 25 columns):
# project_id           19687 non-null object
# relay                19687 non-null float64
# load_v1rms           19687 non-null float64
# load_v2rms           19687 non-null float64
# load_v3rms           19687 non-null float64
# load_i1rms           19687 non-null float64
# load_i2rms           19687 non-null float64
# laod_i3rms           19687 non-null float64
# year                 19687 non-null int64
# month                19687 non-null int64
# day                  19687 non-null int64
# dayofweek            19687 non-null int64
# hour                 19687 non-null int64
# relay_est            19687 non-null int64
# t_diff               19675 non-null float64
# data_issue           19687 non-null int64
# week_hours_outage    17671 non-null float64
# begin_gen            19687 non-null int64
# week_count_outage    17671 non-null float64
# v1rms_hr_std         19654 non-null float64
# v2rms_hr_std         19654 non-null float64
# v3rms_hr_std         19654 non-null float64
# i1rms_hr_std         19654 non-null float64
# i2rms_hr_std         19654 non-null float64
# i3rms_hr_std         19654 non-null float64
# dtypes: float64(16), int64(8), object(1)
# memory usage: 4.5+ MB

# %%
df2.groupby('begin_gen').mean()
# Out:
#               relay  load_v1rms  load_v2rms  load_v3rms  load_i1rms  \
# begin_gen
# 0          0.028857  229.816054  233.501710  234.417368   96.855930
# 1          0.526241  126.049585  127.629295  128.209277   78.415284
#
#            load_i2rms  laod_i3rms    year     month        day  dayofweek  \
# begin_gen
# 0           86.968216   85.117639  2017.0  6.586690  15.968939   3.073273
# 1           74.229495   69.874303  2017.0  6.479167  15.979167   2.604167
#
#                 hour  relay_est  t_diff  data_issue  week_hours_outage  \
# begin_gen
# 0          11.429452   0.029788     1.0         0.0          64.812695
# 1          12.312500   1.000000     1.0         0.0          51.904762
#
#            week_count_outage  v1rms_hr_std  v2rms_hr_std  v3rms_hr_std  \
# begin_gen
# 0                   5.002156      4.415599      4.412079      4.390162
# 1                   4.785714      3.472637      3.426792      3.392866
#
#            i1rms_hr_std  i2rms_hr_std  i3rms_hr_std
# begin_gen
# 0             16.713034     15.503863     10.928552
# 1             18.289407     17.094242     11.788790

# %%
df2.groupby('begin_gen').max()
# Out:
#                                      project_id  relay  load_v1rms  \
# begin_gen
# 0          10742532-49d3-11e7-8d05-f23c91e2b423    1.0  259.229074
# 1          10742532-49d3-11e7-8d05-f23c91e2b423    1.0  233.205198
#
#            load_v2rms  load_v3rms  load_i1rms  load_i2rms  laod_i3rms  year  \
# begin_gen
# 0          261.013741  261.741363  530.656618  539.524321  396.978118  2017
# 1          238.843053  240.710540  269.633529  307.258159  244.250946  2017
#
#            month  day  dayofweek  hour  relay_est  t_diff  data_issue  \
# begin_gen
# 0              8   31          6    23          1     1.0           0
# 1              8   31          6    21          1     1.0           0
#
#            week_hours_outage  week_count_outage  v1rms_hr_std  v2rms_hr_std  \
# begin_gen
# 0                      145.0               10.0    129.105962    130.095629
# 1                      139.0                9.0     84.792569     86.238409
#
#            v3rms_hr_std  i1rms_hr_std  i2rms_hr_std  i3rms_hr_std
# begin_gen
# 0            128.879167    139.107334    138.791232     98.391841
# 1             86.538889    137.996009    136.837765     98.944318
